# %% [markdown]
# import library

# %%
import numpy as np
import pandas as pd

# %%
filename = "C:/Users/faiz_/Desktop/JupyterNotebook/train.csv"

# %% [markdown]
# import excelfile into a variable traindf

# %%
traindf = pd.read_csv(filename)

# %% [markdown]
# set options for pandas dataframe

# %%
#pd.set_option('display.max_rows', 1460)
#pd.set_option('display.max_columns', 81)

# %% [markdown]
# print the data types of each columns

# %%
print(traindf.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# print the total range of traindf

# %%
print(traindf.index)
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %% [markdown]
# print the column name for traindf

# %%
print(traindf.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# print the values of traindf dataset

# %%
print(traindf.values)

# %% [markdown]
# print the first value of traindf dataset

# %%
print(traindf.values[0])

# %% [markdown]
# print the important stats of the dataset such as mean,std deviation, min,max, percentile(1,median,3)

# %%
print(traindf.describe())
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# show a list of information on the dataframe such as datatypes, total data in the each column, null/non-null data

# %%
print(traindf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# sort data by the highest value on the given column

# %%
print(traindf.sort_values("SalePrice", ascending=False))
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
#
# ...

# %% [markdown]
# print value for the given column

# %%
print(traindf.SalePrice)
#print(traindf['SalePrice'])
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# print value for dataset from index 490-500(slicing)

# %%
print(traindf[490:500])
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 490  491         160       RM          NaN     2665   Pave   NaN      Reg
# 491  492          50       RL         79.0     9490   Pave   NaN      Reg
# 492  493          60       RL        105.0    15578   Pave   NaN      IR1
# 493  494          20       RL         70.0     7931   Pave   NaN      Reg
# 494  495          30       RM         50.0     5784   Pave   NaN      Reg
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 496  497          20       RL          NaN    12692   Pave   NaN      IR1
# 497  498          50       RL         60.0     9120   Pave  Pave      Reg
# 498  499          20       RL         65.0     7800   Pave   NaN      Reg
# 499  500          20       RL         70.0     7535   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 490         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# print dataset with given column(multiple)

# %%
print(traindf[['YrSold','SalePrice']])
# Out:
#       YrSold  SalePrice
# 0       2008     208500
# 1       2007     181500
# 2       2008     223500
# 3       2006     140000
# 4       2008     250000
# ...      ...        ...
# 1455    2007     175000
# 1456    2010     210000
# 1457    2010     266500
# 1458    2010     142125
# 1459    2008     147500
#
# [1460 rows x 2 columns]

# %% [markdown]
# loc is label based (take dataset from label), iloc is integer based(take dataset using integer)

# %% [markdown]
# print traindf dataset from index 490-510 with given column names

# %%
print(traindf.loc[490:510,['YrSold','SalePrice']])
# Out:
#      YrSold  SalePrice
# 490    2008     115000
# 491    2006     133000
# 492    2006     172785
# 493    2008     155000
# 494    2009      91300
# 495    2009      34900
# 496    2007     430000
# 497    2008     184000
# 498    2009     130000
# 499    2007     120000
# 500    2007     113000
# 501    2008     226700
# 502    2007     140000
# 503    2010     289000
# 504    2009     147000
# 505    2009     124500
# 506    2006     215000
# 507    2009     208300
# 508    2008     161000
# 509    2009     124500
# 510    2009     164900

# %% [markdown]
# print traindf data from given row(9) and given column(SalePrice)

# %%
print(traindf.loc[9,['SalePrice']])
# Out:
# SalePrice    118000
# Name: 9, dtype: object

# %% [markdown]
# print traindf data from range 490-510 and column 77-80

# %%
print(traindf.iloc[490:510,[77,80]])
# Out:
#      YrSold  SalePrice
# 490    2008     115000
# 491    2006     133000
# 492    2006     172785
# 493    2008     155000
# 494    2009      91300
# 495    2009      34900
# 496    2007     430000
# 497    2008     184000
# 498    2009     130000
# 499    2007     120000
# 500    2007     113000
# 501    2008     226700
# 502    2007     140000
# 503    2010     289000
# 504    2009     147000
# 505    2009     124500
# 506    2006     215000
# 507    2009     208300
# 508    2008     161000
# 509    2009     124500

# %% [markdown]
# print all data from traindf where SalePrice is smaller than 50000

# %%
print(traindf[traindf.SalePrice <50000])
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 30    31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 533  534          20       RL         50.0     5000   Pave   NaN      Reg
# 916  917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968  969          50       RM         50.0     5925   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 30          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 495         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 533         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 916         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 968         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# filter traindf data through given column(RoofStyle) where variable(Gable and Hip) is in the dataset

# %%
print(traindf[traindf.RoofStyle.isin(['Gable','Hip'])])

# %% [markdown]
# assign 10000 to given row(0) and given column(SalePrice)

# %%
traindf.loc[0,['SalePrice']] = 10000

# %% [markdown]
# print traindf values for row 0

# %%
print(traindf.values[0])
# Out:
# [1 60 'RL' 65.0 8450 'Pave' nan 'Reg' 'Lvl' 'AllPub' 'Inside' 'Gtl'
#  'CollgCr' 'Norm' 'Norm' '1Fam' '2Story' 7 5 2003 2003 'Gable' 'CompShg'
#  'VinylSd' 'VinylSd' 'BrkFace' 196.0 'Gd' 'TA' 'PConc' 'Gd' 'TA' 'No'
#  'GLQ' 706 'Unf' 0 150 856 'GasA' 'Ex' 'Y' 'SBrkr' 856 854 0 1710 1 0 2 1
#  3 1 'Gd' 8 'Typ' 0 nan 'Attchd' 2003.0 'RFn' 2 548 'TA' 'TA' 'Y' 0 61 0 0
#  0 0 nan nan nan 0 2 2008 'WD' 'Normal' 10000]

# %% [markdown]
# print the top 20 row of traindf datasets

# %%
print(traindf.head(20))
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# rename column name Saleprice to saleprice

# %%
traindf = traindf.rename(columns= {'SalePrice':'saleprice'})

# %% [markdown]
# print all dataset from traindf in row(YrSold and saleprice) through iteration

# %%
for i, row in traindf.iterrows():
    print(i, row['YrSold'], row['saleprice'])
# Out:
# 0 2008 10000
# 1 2007 181500
# 2 2008 223500
# 3 2006 140000
# 4 2008 250000
# 5 2009 143000
# 6 2007 307000
# 7 2009 200000
# 8 2008 129900
# 9 2008 118000
# 10 2008 129500
# 11 2006 345000
# 12 2008 144000
# 13 2007 279500
# 14 2008 157000
# 15 2007 132000
# 16 2010 149000
# 17 2006 90000
# 18 2008 159000
# 19 2009 139000
# 20 2006 325300
# 21 2007 139400
# 22 2008 230000
# 23 2007 129900
# 24 2010 154000
# 25 2009 256300
# 26 2010 134800
# 27 2010 306000
# 28 2006 207500
# 29 2008 68500
# 30 2008 40000
# 31 2008 149350
# 32 2008 179900
# 33 2010 165500
# 34 2007 277500
# 35 2006 309000
# 36 2009 145000
# 37 2009 153000
# 38 2010 109000
# 39 2008 82000
# 40 2006 160000
# 41 2007 170000
# 42 2007 144000
# 43 2008 130250
# 44 2006 141000
# 45 2010 319900
# 46 2009 239686
# 47 2007 249700
# 48 2009 113000
# 49 2007 127000
# 50 2007 177000
# 51 2006 114500
# 52 2010 110000
# 53 2006 385000
# 54 2007 130000
# 55 2008 180500
# 56 2009 172500
# 57 2006 196500
# 58 2006 438780
# ...

# %% [markdown]
# export traindf data to an excel file in this directory

# %%
traindf.to_csv('C:/Users/faiz_/Desktop/JupyterNotebook/testdata2022.csv')
